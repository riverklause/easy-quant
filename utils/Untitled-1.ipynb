# %%
from utils.settings import settings, get_futu_rsa_key_path

# 默认情况
print(f"默认data_dir: {settings.data.data_dir}")  # "data"
print(f"默认RSA路径: {get_futu_rsa_key_path()}")  # "data/rsa.key"

# 修改data_dir为"c:/dbase"
settings.data.data_dir = "c:/dbase"
print(f"修改后data_dir: {settings.data.data_dir}")  # "c:/dbase"
print(f"修改后RSA路径: {get_futu_rsa_key_path()}")  # "c:/dbase/rsa.key"
# Out:
# 默认data_dir: data
# 默认RSA路径: data\rsa.key
# 修改后data_dir: c:/dbase
# 修改后RSA路径: c:\dbase\rsa.key
