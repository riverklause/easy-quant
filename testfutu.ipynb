# %%
import time
from futu import *
class OrderBookTest(OrderBookHandlerBase):
    def on_recv_rsp(self, rsp_pb):
        ret_code, data = super(OrderBookTest,self).on_recv_rsp(rsp_pb)
        if ret_code != RET_OK:
            print("OrderBookTest: error, msg: %s" % data)
            return RET_ERROR, data
        print("OrderBookTest ", data) # OrderBookTest 自己的处理逻辑
        return RET_OK, data
quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)
quote_ctx1 = OpenQuoteContext(host='127.0.0.1', port=11111)
handler = OrderBookTest()
ret, sdata = quote_ctx1.get_market_snapshot(['HK.00700'])
print('快照数据:', sdata)
quote_ctx.set_handler(handler)  # 设置实时摆盘回调
ret, data = quote_ctx.subscribe(['HK.01951'], [SubType.ORDER_BOOK])  # 订阅买卖摆盘类型，OpenD 开始持续收到服务器的推送
if ret == RET_OK:
    print('实时摆盘:', data)
else:
    print('error:', data)
time.sleep(60)  #  设置脚本接收 OpenD 的推送持续时间为15秒
quote_ctx.close()
quote_ctx1.close()
# Out:
# 2025-11-13 11:05:50,281 | 16188 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=5, host=127.0.0.1, port=11111, user_id=17372346
# 2025-11-13 11:05:50,283 | 16188 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=6, host=127.0.0.1, port=11111, user_id=17372346
# 快照数据:        code  name          update_time  last_price  open_price  high_price  \
# 0  HK.00700  腾讯控股  2025-11-13 11:05:52       650.5       649.5       654.5
#
#    low_price  prev_close_price   volume      turnover  ...  after_change_rate  \
# 0      645.0             657.0  4962075  3.223424e+09  ...                N/A
#
#    after_amplitude overnight_price  overnight_high_price  overnight_low_price  \
# 0              N/A             N/A                   N/A                  N/A
#
#    overnight_volume  overnight_turnover  overnight_change_val  \
# 0               N/A                 N/A                   N/A
#
#    overnight_change_rate  overnight_amplitude
# ...

# %%
import time
from futu import *

class StockQuoteTest(StockQuoteHandlerBase):
    def on_recv_rsp(self, rsp_pb):
        ret_code, data = super(StockQuoteTest,self).on_recv_rsp(rsp_pb)
        if ret_code != RET_OK:
            print("StockQuoteTest: error, msg: %s" % data)
            return RET_ERROR, data
        print("StockQuoteTest ", data) # StockQuoteTest 自己的处理逻辑
        return RET_OK, data
quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)
handler = StockQuoteTest()
quote_ctx.set_handler(handler)  # 设置实时报价回调
ret, data = quote_ctx.subscribe(['HK.01951','HK.00700'], [SubType.QUOTE])  # 订阅实时报价类型，OpenD 开始持续收到服务器的推送
if ret == RET_OK:
    print("订阅成功:", data)
else:
    print('error:', data)
time.sleep(120)  #  设置脚本接收 OpenD 的推送持续时间为15秒
quote_ctx.close()   # 关闭当条连接，OpenD 会在1分钟后自动取消相应股票相应类型的订阅
